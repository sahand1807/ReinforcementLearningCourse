# %%
#https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %% [markdown]
# # 1. Import Dependencies

# %%
import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from typing import Optional # for type hinting

# %% [markdown]
# # 2. Types of Spaces

# %%
Discrete(3)
# Out:
# Discrete(3)

# %%
Discrete(3).sample()
# Out:
# np.int64(2)

# %%
Box(0,1,shape=(3,3)).sample()
# Out:
# array([[0.68517005, 0.74287844, 0.51207143],
#        [0.11664689, 0.55905044, 0.00550268],
#        [0.27708128, 0.00790686, 0.34266573]], dtype=float32)

# %%
Box(0,255,shape=(3,3), dtype=int).sample()
# Out:
# array([[ 78,  70,  52],
#        [244,  44, 161],
#        [ 62,  32,   2]])

# %%
Tuple((Discrete(2), Box(0,100, shape=(1,)))).sample()
# Out:
# (np.int64(1), array([35.283913], dtype=float32))

# %%
Dict({'height':Discrete(2), "speed":Box(0,100, shape=(1,))}).sample()
# Out:
# {'height': np.int64(0), 'speed': array([39.625473], dtype=float32)}

# %%
MultiBinary(4).sample()
# Out:
# array([0, 1, 1, 1], dtype=int8)

# %%
MultiDiscrete([5,2,3]).sample()
# Out:
# array([3, 1, 0])

# %% [markdown]
# # 3. Building an Environment

# %%
class ShowerEnv(Env):
    """A custom environment for a shower temperature control problem."""
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3) # 0,1,2 for down, stay, up
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward (1 for 37-39, else -1)
        if self.state >=37 and self.state <=39: 
            reward =1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            terminated = True
        else:
            terminated = False
        truncated = False
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, terminated, truncated, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self, seed: Optional[int] = None, options: Optional[dict] = None):
        super().reset(seed=seed)
        # Reset shower temperature
        self.state = np.array([38 + random.randint(-3,3)]).astype(np.float32)
        # Reset shower time
        self.shower_length = 60 
        info = {}
        return self.state, info

# %%
env=ShowerEnv()

# %%
env.observation_space.sample()
# Out:
# array([96.43866], dtype=float32)

# %%
env.reset()
# Out:
# array([37.])

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)

# %% [markdown]
# # 4. Test Environment

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-18
# Episode:2 Score:-60
# Episode:3 Score:-14
# Episode:4 Score:-54
# Episode:5 Score:-40

# %%
env.close()

# %% [markdown]
# # 5. Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training/Logs/PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -31.1    |
# | time/              |          |
# |    fps             | 7000     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -29.4        |
# | time/                   |              |
# |    fps                  | 4353         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0039025033 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000523    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.4         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 56.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29.8       |
# | time/                   |             |
# |    fps                  | 4102        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008529216 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.000249   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 60.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.6       |
# | time/                   |             |
# |    fps                  | 4001        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.001737593 |
# |    clip_fraction        | 0.0041      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.0017     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000953   |
# |    value_loss           | 67.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -27.4       |
# | time/                   |             |
# |    fps                  | 3948        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012116504 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -9.47e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00869    |
# |    value_loss           | 66.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -23        |
# | time/                   |            |
# |    fps                  | 3911       |
# |    iterations           | 6          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00668882 |
# |    clip_fraction        | 0.0244     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -9.42e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28         |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.000521  |
# |    value_loss           | 65.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -22.1        |
# | time/                   |              |
# |    fps                  | 3872         |
# |    iterations           | 7            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0016643661 |
# |    clip_fraction        | 0.0064       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -4.36e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.6         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000289    |
# |    value_loss           | 65.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -23.7       |
# | time/                   |             |
# |    fps                  | 3818        |
# |    iterations           | 8           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012449885 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00303    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 68.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.8       |
# | time/                   |             |
# |    fps                  | 3802        |
# |    iterations           | 9           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013231392 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00247    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 63.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -30.5      |
# | time/                   |            |
# |    fps                  | 3789       |
# |    iterations           | 10         |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00812714 |
# |    clip_fraction        | 0.0557     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | 0.00116    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.7       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00621   |
# |    value_loss           | 63.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29         |
# | time/                   |             |
# |    fps                  | 3782        |
# |    iterations           | 11          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006393555 |
# |    clip_fraction        | 0.0379      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00173     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 71.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.9       |
# | time/                   |             |
# |    fps                  | 3773        |
# |    iterations           | 12          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012478682 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00386    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.7        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00866    |
# |    value_loss           | 72.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.3       |
# | time/                   |             |
# |    fps                  | 3763        |
# |    iterations           | 13          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014541835 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.000285    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.9        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 60.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -25.9        |
# | time/                   |              |
# |    fps                  | 3759         |
# |    iterations           | 14           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0096274465 |
# |    clip_fraction        | 0.0891       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00311     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28           |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00667     |
# |    value_loss           | 61.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -23.8       |
# | time/                   |             |
# |    fps                  | 3758        |
# |    iterations           | 15          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008411293 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.000186    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.1        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 65.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 3756        |
# |    iterations           | 16          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009416883 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.00436     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.8        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00636    |
# |    value_loss           | 62          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -20.8       |
# | time/                   |             |
# |    fps                  | 3754        |
# |    iterations           | 17          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012853107 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0152     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 73.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -17.7        |
# | time/                   |              |
# |    fps                  | 3754         |
# |    iterations           | 18           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0049136374 |
# |    clip_fraction        | 0.0935       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.000203     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.1         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00655     |
# |    value_loss           | 77.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -14.3       |
# | time/                   |             |
# |    fps                  | 3752        |
# |    iterations           | 19          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010223625 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.005      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 52.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -8.66       |
# | time/                   |             |
# |    fps                  | 3751        |
# |    iterations           | 20          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004339032 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00127    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 56.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -6.1         |
# | time/                   |              |
# |    fps                  | 3750         |
# |    iterations           | 21           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0077129374 |
# |    clip_fraction        | 0.0879       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.0137       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.4         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00762     |
# |    value_loss           | 51.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -3.54       |
# | time/                   |             |
# |    fps                  | 3750        |
# |    iterations           | 22          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007915823 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.0394     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.7        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 48.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 3749       |
# |    iterations           | 23         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01038906 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.000663   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.4       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 39.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 5.32        |
# | time/                   |             |
# |    fps                  | 3739        |
# |    iterations           | 24          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012195414 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.00656     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.6        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 34.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 12.5        |
# | time/                   |             |
# |    fps                  | 3731        |
# |    iterations           | 25          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008885886 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.0166     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 30.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 3731        |
# |    iterations           | 26          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010224719 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.0014      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0088     |
# |    value_loss           | 25.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 23.6        |
# | time/                   |             |
# |    fps                  | 3731        |
# |    iterations           | 27          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010441213 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | -0.00106    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00896    |
# |    value_loss           | 27.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 28.1        |
# | time/                   |             |
# |    fps                  | 3730        |
# |    iterations           | 28          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.020489827 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0.000367    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00149     |
# |    value_loss           | 28.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 31.7        |
# | time/                   |             |
# |    fps                  | 3730        |
# |    iterations           | 29          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010915673 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | 0.00049     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000968   |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 33.4        |
# | time/                   |             |
# |    fps                  | 3730        |
# |    iterations           | 30          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014071152 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | -6.2e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00987     |
# |    value_loss           | 40          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 36.3        |
# | time/                   |             |
# |    fps                  | 3729        |
# |    iterations           | 31          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.033857673 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | 0.000117    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.000993   |
# |    value_loss           | 45          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 3729        |
# |    iterations           | 32          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.022152204 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | -6.97e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.4        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00188     |
# |    value_loss           | 51.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.6        |
# | time/                   |             |
# |    fps                  | 3730        |
# |    iterations           | 33          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014618439 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 3.01e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.3        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00843     |
# |    value_loss           | 57.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.4        |
# | time/                   |             |
# |    fps                  | 3729        |
# |    iterations           | 34          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006410527 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 2e-05       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30          |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00285     |
# |    value_loss           | 61.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 39.6         |
# | time/                   |              |
# |    fps                  | 3729         |
# |    iterations           | 35           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0068162284 |
# |    clip_fraction        | 0.187        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.939       |
# |    explained_variance   | 1.2e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.8         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.011        |
# |    value_loss           | 63.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 38.2        |
# | time/                   |             |
# |    fps                  | 3729        |
# |    iterations           | 36          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.024588417 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | -1.36e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.8        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00487     |
# |    value_loss           | 61.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 37          |
# | time/                   |             |
# |    fps                  | 3728        |
# |    iterations           | 37          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.017477239 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | -7.01e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.8        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 61.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.4        |
# | time/                   |             |
# |    fps                  | 3728        |
# |    iterations           | 38          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012323571 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.927      |
# |    explained_variance   | -5.07e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00953     |
# |    value_loss           | 62.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.4        |
# | time/                   |             |
# |    fps                  | 3728        |
# |    iterations           | 39          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010785826 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | -1.6e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.9        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00449     |
# |    value_loss           | 63.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39.1        |
# | time/                   |             |
# |    fps                  | 3728        |
# |    iterations           | 40          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012423478 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.927      |
# |    explained_variance   | -4.41e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.7        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00878     |
# |    value_loss           | 68.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39.8        |
# | time/                   |             |
# |    fps                  | 3728        |
# |    iterations           | 41          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.017100144 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | -2.1e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.6        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00632    |
# |    value_loss           | 64.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.9        |
# | time/                   |             |
# |    fps                  | 3727        |
# |    iterations           | 42          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.030566026 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | -1.84e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.7        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00611     |
# |    value_loss           | 58.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 45.3       |
# | time/                   |            |
# |    fps                  | 3727       |
# |    iterations           | 43         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01217968 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.926     |
# |    explained_variance   | 5.96e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.1       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.0106     |
# |    value_loss           | 67.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.8        |
# | time/                   |             |
# |    fps                  | 3727        |
# |    iterations           | 44          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.021194357 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 7.09e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00278     |
# |    value_loss           | 72.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.2        |
# | time/                   |             |
# |    fps                  | 3727        |
# |    iterations           | 45          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.058664378 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 7.33e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0109      |
# |    value_loss           | 69.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 41.7       |
# | time/                   |            |
# |    fps                  | 3725       |
# |    iterations           | 46         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01693641 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.906     |
# |    explained_variance   | 1.22e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38.4       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.0039     |
# |    value_loss           | 72.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 40.9       |
# | time/                   |            |
# |    fps                  | 3726       |
# |    iterations           | 47         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01592793 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.914     |
# |    explained_variance   | 9e-06      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.4       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.0065     |
# |    value_loss           | 63.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.7        |
# | time/                   |             |
# |    fps                  | 3727        |
# |    iterations           | 48          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.025330294 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | 2.55e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.2        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 68.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.8        |
# | time/                   |             |
# |    fps                  | 3727        |
# |    iterations           | 49          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.071640044 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.000388    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0167      |
# |    value_loss           | 65.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 49         |
# | time/                   |            |
# |    fps                  | 3727       |
# |    iterations           | 50         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.06243743 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.913     |
# |    explained_variance   | -7.39e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.8       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.0183     |
# |    value_loss           | 71.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.8        |
# | time/                   |             |
# |    fps                  | 3726        |
# |    iterations           | 51          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.055938087 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.6        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0153      |
# |    value_loss           | 82.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 51.5       |
# | time/                   |            |
# |    fps                  | 3726       |
# |    iterations           | 52         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.03458193 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.866     |
# |    explained_variance   | 8.94e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 41.5       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.0205     |
# |    value_loss           | 88.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 51.1       |
# | time/                   |            |
# |    fps                  | 3726       |
# |    iterations           | 53         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.01330402 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.864     |
# |    explained_variance   | -4.77e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 61.4       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0133     |
# |    value_loss           | 91         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.5        |
# | time/                   |             |
# |    fps                  | 3726        |
# |    iterations           | 54          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.011845497 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.2        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.0141      |
# |    value_loss           | 92.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.5        |
# | time/                   |             |
# |    fps                  | 3726        |
# |    iterations           | 55          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.017795399 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 1.19e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.9        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.0181      |
# |    value_loss           | 91.4        |
# -----------------------------------------
# ----------------------------------------
# ...
# |    value_loss           | 117         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 57.1       |
# | time/                   |            |
# |    fps                  | 3707       |
# |    iterations           | 179        |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 366592     |
# | train/                  |            |
# |    approx_kl            | 0.04008662 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.866     |
# |    explained_variance   | -2.28e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 54         |
# |    n_updates            | 1780       |
# |    policy_gradient_loss | 0.0139     |
# |    value_loss           | 116        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.2        |
# | time/                   |             |
# |    fps                  | 3707        |
# |    iterations           | 180         |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.046319097 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | -3.7e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.9        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.0202      |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.8        |
# | time/                   |             |
# |    fps                  | 3706        |
# |    iterations           | 181         |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.017723557 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | -1.96e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.2        |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | 0.0164      |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.1        |
# | time/                   |             |
# |    fps                  | 3706        |
# |    iterations           | 182         |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.018952357 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | -1.41e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.4        |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.0148      |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.6        |
# | time/                   |             |
# |    fps                  | 3706        |
# |    iterations           | 183         |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.026527617 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | -5.92e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.8        |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.0107      |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.9        |
# | time/                   |             |
# |    fps                  | 3706        |
# |    iterations           | 184         |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.017538408 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.856      |
# |    explained_variance   | -3.11e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.1        |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | 0.0178      |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.5        |
# | time/                   |             |
# |    fps                  | 3706        |
# |    iterations           | 185         |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.005517329 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | -3.14e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.7        |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.0116      |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57          |
# | time/                   |             |
# |    fps                  | 3706        |
# |    iterations           | 186         |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.011660108 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | -2.66e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.5        |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | 0.0137      |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.6        |
# | time/                   |             |
# |    fps                  | 3706        |
# |    iterations           | 187         |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.030794697 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.848      |
# |    explained_variance   | -1.42e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.9        |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.0149      |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.4        |
# | time/                   |             |
# |    fps                  | 3705        |
# |    iterations           | 188         |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.027871076 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | -1.26e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.6        |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | 0.00815     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.9        |
# | time/                   |             |
# |    fps                  | 3705        |
# |    iterations           | 189         |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.015186668 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | 2.92e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.6        |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | 0.0158      |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.1        |
# | time/                   |             |
# |    fps                  | 3705        |
# |    iterations           | 190         |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.009270738 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | -4.41e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.4        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | 0.0147      |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.9        |
# | time/                   |             |
# |    fps                  | 3705        |
# |    iterations           | 191         |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.015469821 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | -6.32e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.3        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.0218      |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.4        |
# | time/                   |             |
# |    fps                  | 3705        |
# |    iterations           | 192         |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.015956335 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | 7.33e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.6        |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.0162      |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54          |
# | time/                   |             |
# |    fps                  | 3705        |
# |    iterations           | 193         |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.017427634 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.848      |
# |    explained_variance   | -9.54e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.6        |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.00733     |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 55.2         |
# | time/                   |              |
# |    fps                  | 3705         |
# |    iterations           | 194          |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 0.0114712585 |
# |    clip_fraction        | 0.163        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 2.53e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.4         |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | 0.00813      |
# |    value_loss           | 108          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.7        |
# | time/                   |             |
# |    fps                  | 3705        |
# |    iterations           | 195         |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.005591031 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 7.57e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.5        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | 0.00664     |
# |    value_loss           | 111         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.9        |
# | time/                   |             |
# |    fps                  | 3705        |
# |    iterations           | 196         |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.014365628 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | -7.03e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.9        |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.00932     |
# |    value_loss           | 110         |
# -----------------------------------------

# %% [markdown]
# # 6. Save Model

# %%
save_path = os.path.join('Training', 'Saved Models', 'PPO_shower_env')
model.save(save_path)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, render=False)
print(f'Mean reward: {mean_reward} +/- {std_reward}')
# Out:
# Mean reward: 59.0 +/- 1.0
